# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_excel('Book1.xlsx')

# %%
X = data[['Outlook', 'Temp']]  # Replace 'feature1', 'feature2', ... with the names of your features

# %%
kmeans = KMeans(n_clusters=3, random_state=42)  # You can adjust the number of clusters as needed

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
cluster_centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
plt.scatter(X['Outlook'], X['Temp'], c=labels, cmap='viridis')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='x', color='red', s=200, label='Cluster Centers')
plt.title('KMeans Clustering')
plt.xlabel('Outlook')
plt.ylabel('Temp')
plt.legend()
plt.show()
